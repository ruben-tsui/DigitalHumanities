# %%
from bs4 import BeautifulSoup, NavigableString
from urllib import request, parse
import re, time

# %%
BIO_LINKS = set()
fon = 'bio300to510AD.txt'
fo  = open(fon, "w", encoding="utf-8", newline="\n")

# %%
base_url = 'zh.wikipedia.org'

# %%
for year in range(300, 511):
    url = fr"{base_url}/wiki/Category:{year}年出生"
    print(url)
    req  = request.Request('http://'+parse.quote(url), headers={'User-Agent': 'Mozilla/5.0'})
    try:
        page = request.urlopen(req)
    except:
        continue
    soup = BeautifulSoup(page, 'lxml')
    nodes = soup.find_all('a', {'title':re.compile(r'[一-鿕]+'), 'href':re.compile(r'/wiki/%')}, recursive=True, limit=2000)
    for child in nodes:
        link = child['href']
        if link.startswith('/wiki'):
            article = f"{base_url}{child['href']}"
            article = article.replace(r'/wiki/', r'/zh-tw/')
            fo.write(f"{article}\n")
            BIO_LINKS.add(article)
    
    time.sleep(0.5)

fo.close()
# Out:
# zh.wikipedia.org/wiki/Category:300年出生
# zh.wikipedia.org/wiki/Category:301年出生
# zh.wikipedia.org/wiki/Category:302年出生
# zh.wikipedia.org/wiki/Category:303年出生
# zh.wikipedia.org/wiki/Category:304年出生
# zh.wikipedia.org/wiki/Category:305年出生
# zh.wikipedia.org/wiki/Category:306年出生
# zh.wikipedia.org/wiki/Category:307年出生
# zh.wikipedia.org/wiki/Category:308年出生
# zh.wikipedia.org/wiki/Category:309年出生
# zh.wikipedia.org/wiki/Category:310年出生
# zh.wikipedia.org/wiki/Category:311年出生
# zh.wikipedia.org/wiki/Category:312年出生
# zh.wikipedia.org/wiki/Category:313年出生
# zh.wikipedia.org/wiki/Category:314年出生
# zh.wikipedia.org/wiki/Category:315年出生
# zh.wikipedia.org/wiki/Category:316年出生
# zh.wikipedia.org/wiki/Category:317年出生
# zh.wikipedia.org/wiki/Category:318年出生
# zh.wikipedia.org/wiki/Category:319年出生
# zh.wikipedia.org/wiki/Category:320年出生
# zh.wikipedia.org/wiki/Category:321年出生
# zh.wikipedia.org/wiki/Category:322年出生
# zh.wikipedia.org/wiki/Category:323年出生
# zh.wikipedia.org/wiki/Category:324年出生
# zh.wikipedia.org/wiki/Category:325年出生
# zh.wikipedia.org/wiki/Category:326年出生
# zh.wikipedia.org/wiki/Category:327年出生
# zh.wikipedia.org/wiki/Category:328年出生
# zh.wikipedia.org/wiki/Category:329年出生
# zh.wikipedia.org/wiki/Category:330年出生
# zh.wikipedia.org/wiki/Category:331年出生
# zh.wikipedia.org/wiki/Category:332年出生
# zh.wikipedia.org/wiki/Category:333年出生
# zh.wikipedia.org/wiki/Category:334年出生
# zh.wikipedia.org/wiki/Category:335年出生
# zh.wikipedia.org/wiki/Category:336年出生
# zh.wikipedia.org/wiki/Category:337年出生
# zh.wikipedia.org/wiki/Category:338年出生
# zh.wikipedia.org/wiki/Category:339年出生
# zh.wikipedia.org/wiki/Category:340年出生
# zh.wikipedia.org/wiki/Category:341年出生
# zh.wikipedia.org/wiki/Category:342年出生
# zh.wikipedia.org/wiki/Category:343年出生
# zh.wikipedia.org/wiki/Category:344年出生
# zh.wikipedia.org/wiki/Category:345年出生
# zh.wikipedia.org/wiki/Category:346年出生
# zh.wikipedia.org/wiki/Category:347年出生
# zh.wikipedia.org/wiki/Category:348年出生
# zh.wikipedia.org/wiki/Category:417年出生
# zh.wikipedia.org/wiki/Category:418年出生
# zh.wikipedia.org/wiki/Category:419年出生
# zh.wikipedia.org/wiki/Category:420年出生
# zh.wikipedia.org/wiki/Category:421年出生
# zh.wikipedia.org/wiki/Category:422年出生
# zh.wikipedia.org/wiki/Category:423年出生
# zh.wikipedia.org/wiki/Category:424年出生
# zh.wikipedia.org/wiki/Category:425年出生
# zh.wikipedia.org/wiki/Category:426年出生
# zh.wikipedia.org/wiki/Category:427年出生
# zh.wikipedia.org/wiki/Category:428年出生
# zh.wikipedia.org/wiki/Category:429年出生
# zh.wikipedia.org/wiki/Category:430年出生
# zh.wikipedia.org/wiki/Category:431年出生
# zh.wikipedia.org/wiki/Category:432年出生
# zh.wikipedia.org/wiki/Category:433年出生
# zh.wikipedia.org/wiki/Category:434年出生
# zh.wikipedia.org/wiki/Category:435年出生
# zh.wikipedia.org/wiki/Category:436年出生
# zh.wikipedia.org/wiki/Category:437年出生
# zh.wikipedia.org/wiki/Category:438年出生
# zh.wikipedia.org/wiki/Category:439年出生
# zh.wikipedia.org/wiki/Category:440年出生
# zh.wikipedia.org/wiki/Category:441年出生
# zh.wikipedia.org/wiki/Category:442年出生
# zh.wikipedia.org/wiki/Category:443年出生
# zh.wikipedia.org/wiki/Category:444年出生
# zh.wikipedia.org/wiki/Category:445年出生
# zh.wikipedia.org/wiki/Category:446年出生
# zh.wikipedia.org/wiki/Category:447年出生
# zh.wikipedia.org/wiki/Category:448年出生
# zh.wikipedia.org/wiki/Category:449年出生
# zh.wikipedia.org/wiki/Category:450年出生
# zh.wikipedia.org/wiki/Category:451年出生
# zh.wikipedia.org/wiki/Category:452年出生
# zh.wikipedia.org/wiki/Category:453年出生
# zh.wikipedia.org/wiki/Category:454年出生
# zh.wikipedia.org/wiki/Category:455年出生
# zh.wikipedia.org/wiki/Category:456年出生
# zh.wikipedia.org/wiki/Category:457年出生
# zh.wikipedia.org/wiki/Category:458年出生
# zh.wikipedia.org/wiki/Category:459年出生
# zh.wikipedia.org/wiki/Category:460年出生
# zh.wikipedia.org/wiki/Category:461年出生
# zh.wikipedia.org/wiki/Category:462年出生
# zh.wikipedia.org/wiki/Category:463年出生
# zh.wikipedia.org/wiki/Category:464年出生
# zh.wikipedia.org/wiki/Category:465年出生
# zh.wikipedia.org/wiki/Category:466年出生
# zh.wikipedia.org/wiki/Category:467年出生
# zh.wikipedia.org/wiki/Category:468年出生
# zh.wikipedia.org/wiki/Category:469年出生
# zh.wikipedia.org/wiki/Category:470年出生
# zh.wikipedia.org/wiki/Category:471年出生
# zh.wikipedia.org/wiki/Category:472年出生
# zh.wikipedia.org/wiki/Category:473年出生
# zh.wikipedia.org/wiki/Category:474年出生
# zh.wikipedia.org/wiki/Category:475年出生
# zh.wikipedia.org/wiki/Category:476年出生
# zh.wikipedia.org/wiki/Category:477年出生
# zh.wikipedia.org/wiki/Category:478年出生
# zh.wikipedia.org/wiki/Category:479年出生
# zh.wikipedia.org/wiki/Category:480年出生
# zh.wikipedia.org/wiki/Category:481年出生
# zh.wikipedia.org/wiki/Category:482年出生
# zh.wikipedia.org/wiki/Category:483年出生
# zh.wikipedia.org/wiki/Category:484年出生
# zh.wikipedia.org/wiki/Category:485年出生
# zh.wikipedia.org/wiki/Category:486年出生
# zh.wikipedia.org/wiki/Category:487年出生
# zh.wikipedia.org/wiki/Category:488年出生
# zh.wikipedia.org/wiki/Category:489年出生
# zh.wikipedia.org/wiki/Category:490年出生
# zh.wikipedia.org/wiki/Category:491年出生
# zh.wikipedia.org/wiki/Category:492年出生
# zh.wikipedia.org/wiki/Category:493年出生
# zh.wikipedia.org/wiki/Category:494年出生
# zh.wikipedia.org/wiki/Category:495年出生
# zh.wikipedia.org/wiki/Category:496年出生
# zh.wikipedia.org/wiki/Category:497年出生
# zh.wikipedia.org/wiki/Category:498年出生
# zh.wikipedia.org/wiki/Category:499年出生
# zh.wikipedia.org/wiki/Category:500年出生
# zh.wikipedia.org/wiki/Category:501年出生
# zh.wikipedia.org/wiki/Category:502年出生
# zh.wikipedia.org/wiki/Category:503年出生
# zh.wikipedia.org/wiki/Category:504年出生
# zh.wikipedia.org/wiki/Category:505年出生
# zh.wikipedia.org/wiki/Category:506年出生
# zh.wikipedia.org/wiki/Category:507年出生
# zh.wikipedia.org/wiki/Category:508年出生
# zh.wikipedia.org/wiki/Category:509年出生
# zh.wikipedia.org/wiki/Category:510年出生

# %%
fo.close()

# %%
fon = 'bio300to510AD_initial_text.txt'
fo  = open(fon, "w", encoding="utf-8", newline="\n")

# %%
BeginTime = time.time()

cnt = 0
for link in BIO_LINKS:
    cnt += 1
    if cnt % 50 == 0:
        fo.flush()
        print(cnt)
    fo.write(link + "\n")
    req  = request.Request(f"http://{link}", headers={'User-Agent': 'Mozilla/5.0'})
    try:
        page = request.urlopen(req)
    except:
        continue
    soup = BeautifulSoup(page, 'lxml')
    headword = ''
    h1s = soup.find_all('h1')
    if len(h1s) > 0:
        headword = h1s[0].text
    fo.write(headword + "\n")
        
    nodes = soup.find_all('div', {'class':'mw-parser-output'})
    ## in each "div", the first <p></p> seems to contain the information (name, YOB, YOD, courtesy name, place names) 
    
    if len(nodes) > 0:
        #print(len(nodes))
        div = nodes[0]
        basic_info = list(div.find_all('p', recursive=False))
        #print(f"No. of <p> nodes: {len(basic_info)}")
        for paragraph in basic_info:  # <p></p>
            children = list(paragraph.children)
            if children[0].name == 'a': # if this <p> node contains a URL link, skip
                print(f"Skipping node {str(paragraph)}")
                continue
            else:
                if isinstance(paragraph, NavigableString):
                    fo.write(paragraph.strip() + "\n")
                else:
                    fo.write(paragraph.text.strip() + "\n")
                break # done!
        fo.write('-'*20 + "\n")
    else:
        fo.write("No info available for this entry\n")
    #if cnt > 50:
    #    break

fo.close()
EndTime = time.time()
ElapsedTime = EndTime - BeginTime
print("Done! Total time elapsed: [%.4f] sec(s)" % ElapsedTime) if True else ""
# Out:
# 50
# 100
# Skipping node <p><a href="/wiki/%E6%95%99%E5%AE%97" title="教宗">教宗</a><a class="mw-redirect" href="/wiki/%E8%81%96%E4%BA%BA" title="聖人">聖</a><b>良一世</b>（<a class="mw-redirect" href="/wiki/%E6%8B%89%E4%B8%81%E8%AA%9E" title="拉丁語">拉丁語</a>：<span lang="la">Sanctus Leo PP. I</span>，400年－461年11月10日），440年9月29日至461年11月10日任教宗。
# </p>
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# Done! Total time elapsed: [1180.2351] sec(s)

# %%
fo.close()
